# %%
from os import listdir

# %%
listdir('/home/jovyan/shared/ds003097/derivatives/')
# Out:
# ['dwipreproc',
#  'fmriprep',
#  'freesurfer',
#  'fs_stats',
#  'mriqc',
#  'physiology',
#  'vbm']

# %%
sub_peek = 'sub-0002'

# %%
listdir(f'/home/jovyan/shared/ds003097/derivatives/fmriprep/{sub_peek}/')
# Out:
# ['anat', 'figures', 'func']

# %%
listdir(f'/home/jovyan/shared/ds003097/derivatives/fmriprep/{sub_peek}/anat/')
# Out:
# ['sub-0002_desc-aparcaseg_dseg.nii.gz',
#  'sub-0002_desc-aseg_dseg.nii.gz',
#  'sub-0002_desc-brain_mask.json',
#  'sub-0002_desc-brain_mask.nii.gz',
#  'sub-0002_desc-preproc_T1w.json',
#  'sub-0002_desc-preproc_T1w.nii.gz',
#  'sub-0002_dseg.nii.gz',
#  'sub-0002_from-MNI152NLin2009cAsym_to-T1w_mode-image_xfm.h5',
#  'sub-0002_from-T1w_to-MNI152NLin2009cAsym_mode-image_xfm.h5',
#  'sub-0002_from-T1w_to-fsnative_mode-image_xfm.txt',
#  'sub-0002_hemi-L_inflated.surf.gii',
#  'sub-0002_hemi-L_midthickness.surf.gii',
#  'sub-0002_hemi-L_pial.surf.gii',
#  'sub-0002_hemi-L_smoothwm.surf.gii',
#  'sub-0002_hemi-R_inflated.surf.gii',
#  'sub-0002_hemi-R_midthickness.surf.gii',
#  'sub-0002_hemi-R_pial.surf.gii',
#  'sub-0002_hemi-R_smoothwm.surf.gii',
#  'sub-0002_label-CSF_probseg.nii.gz',
#  'sub-0002_label-GM_probseg.nii.gz',
#  'sub-0002_label-WM_probseg.nii.gz',
#  'sub-0002_run-1_from-orig_to-T1w_mode-image_xfm.txt',
#  'sub-0002_run-2_from-orig_to-T1w_mode-image_xfm.txt',
#  'sub-0002_run-3_from-orig_to-T1w_mode-image_xfm.txt',
#  'sub-0002_space-MNI152NLin2009cAsym_desc-brain_mask.json',
#  'sub-0002_space-MNI152NLin2009cAsym_desc-brain_mask.nii.gz',
#  'sub-0002_space-MNI152NLin2009cAsym_desc-preproc_T1w.json',
#  'sub-0002_space-MNI152NLin2009cAsym_desc-preproc_T1w.nii.gz',
#  'sub-0002_space-MNI152NLin2009cAsym_dseg.nii.gz',
#  'sub-0002_space-MNI152NLin2009cAsym_label-CSF_probseg.nii.gz',
#  'sub-0002_space-MNI152NLin2009cAsym_label-GM_probseg.nii.gz',
#  'sub-0002_space-MNI152NLin2009cAsym_label-WM_probseg.nii.gz']

# %%
listdir(f'/home/jovyan/shared/ds003097/derivatives/fmriprep/{sub_peek}/func/')
# Out:
# ['sub-0002_task-moviewatching_desc-confounds_regressors.json',
#  'sub-0002_task-moviewatching_desc-confounds_regressors.tsv',
#  'sub-0002_task-moviewatching_space-MNI152NLin2009cAsym_boldref.nii.gz',
#  'sub-0002_task-moviewatching_space-MNI152NLin2009cAsym_desc-aparcaseg_dseg.nii.gz',
#  'sub-0002_task-moviewatching_space-MNI152NLin2009cAsym_desc-aseg_dseg.nii.gz',
#  'sub-0002_task-moviewatching_space-MNI152NLin2009cAsym_desc-brain_mask.json',
#  'sub-0002_task-moviewatching_space-MNI152NLin2009cAsym_desc-brain_mask.nii.gz',
#  'sub-0002_task-moviewatching_space-MNI152NLin2009cAsym_desc-preproc_bold.json',
#  'sub-0002_task-moviewatching_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz',
#  'sub-0002_task-moviewatching_space-T1w_boldref.nii.gz',
#  'sub-0002_task-moviewatching_space-T1w_desc-aparcaseg_dseg.nii.gz',
#  'sub-0002_task-moviewatching_space-T1w_desc-aseg_dseg.nii.gz',
#  'sub-0002_task-moviewatching_space-T1w_desc-brain_mask.json',
#  'sub-0002_task-moviewatching_space-T1w_desc-brain_mask.nii.gz',
#  'sub-0002_task-moviewatching_space-T1w_desc-preproc_bold.json',
#  'sub-0002_task-moviewatching_space-T1w_desc-preproc_bold.nii.gz',
#  'sub-0002_task-moviewatching_space-fsaverage5_hemi-L.func.gii',
#  'sub-0002_task-moviewatching_space-fsaverage5_hemi-R.func.gii']

# %%
import nibabel as nib

# %%
data = nib.load(f'/home/jovyan/shared/ds003097/derivatives/fmriprep/{sub_peek}/func/{sub_peek}_task-moviewatching_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz')\
    .get_fdata()

# %%
data.shape
# Out:
# (60, 77, 65, 290)

# %%
data.min()
# Out:
# -54.09619140625

# %%
data.max()
# Out:
# 781.1727404529229

# %%
data.mean()
# Out:
# 77.81164170178707

# %%
anat_data = nib.load(f'/home/jovyan/shared/ds003097/derivatives/fmriprep/{sub_peek}/anat/{sub_peek}_space-MNI152NLin2009cAsym_desc-preproc_T1w.nii.gz')\
    .get_fdata()

# %%
anat_data.shape
# Out:
# (193, 229, 193)

# %%
anat_data.min()
# Out:
# -824.8975219726562

# %%
anat_data.max()
# Out:
# 31777.478515625

# %%
anat_data.mean()
# Out:
# 3220.8050241177875

# %%
from nilearn import plotting

# %%
plot_anat(f'/home/jovyan/shared/ds003097/derivatives/fmriprep/{sub_peek}/anat/{sub_peek}_space-MNI152NLin2009cAsym_desc-preproc_T1w.nii.gz')

# %%
func_file = f'/home/jovyan/shared/ds003097/derivatives/fmriprep/{sub_peek}/func/{sub_peek}_task-moviewatching_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz'

# %%
# plot functional scan 
from nilearn.image import mean_img # so that we can average over time 
plotting.view_img(mean_img(func_file), threshold=None)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;title&gt;Slice viewer&lt;/title&gt;
#     &lt;meta charset=&quot;UTF-8&quot; /&gt;
# &lt;/head&gt;
# &lt;body&gt;
#   &lt;div id=&quot;div_viewer&quot;&gt;
#     &lt;!-- this is the canvas that will feature the brain slices --&gt;
#     &lt;canvas id=&quot;3Dviewer&quot;&gt;
#     &lt;!-- load a hidden version of the sprite image that includes all (sagital) brain slices --&gt;
#     &lt;img id=&quot;spriteImg&quot; class=&quot;hidden&quot; src=&quot;data:image/png;base64,...&quot; alt=&quot;background&quot; /&gt;
#     &lt;!-- the colormap --&gt;
#     &lt;img id=&quot;colorMap&quot; class=&quot;hidden&quot; src=&quot;...&quot; alt=&quot;colormap&quot;&gt;
#     &lt;!-- another sprite image, with an overlay--&gt;
#     &lt;img id=&quot;overlayImg&quot; class=&quot;hidden&quot; src=&quot;data:image/png;base64,...&quot; alt=&quot;overlay&quot;&gt;
#     &lt;/canvas&gt;
#   &lt;/div&gt;
#
#   &lt;script&gt;
#     /*! jQuery v3.6.0 | (c) OpenJS Foundation and other contributors | jquery.org/license */
# !function(e,t){&quot;use strict&quot;;&quot;object&quot;==typeof module&amp;&amp;&quot;object&quot;==typeof module.exports?module.exports=e.document?t(e,!0):function(e){if(!e.document)throw new Error(&quot;jQuery requires a window with a document&quot;);return t(e)}:t(e)}(&quot;undefined&quot;!=typeof window?window:this,function(C,e){&quot;use strict&quot;;var t=[],r=Object.getPrototypeOf,s=t.slice,g=t.flat?function(e){return t.flat.call(e)}:function(e){return t.concat.apply([],e)},u=t.push,i=t.indexOf,n={},o=n.toString,v=n.hasOwnProperty,a=v.toString,l=a.call(Object),y={},m=function(e){return&quot;function&quot;==typeof e&amp;&amp;&quot;number&quot;!=typeof e.nodeType&amp;&amp;&quot;function&quot;!=typeof e.item},x=function(e){return null!=e&amp;&amp;e===e.window},E=C.document,c={type:!0,src:!0,nonce:!0,noModule:!0};function b(e,t,n){var r,i,o=(n=n||E).createElement(&quot;script&quot;);if(o.text=e,t)for(r in c)(i=t[r]||t.getAttribute&amp;&amp;t.getAttribute(r))&amp;&amp;o.setAttribute(r,i);n.head.appendChild(o).parentNode.removeChild(o)}function w(e){return null==e?e+&quot;&quot;:&quot;object&quot;==typeof e||&quot;function&quot;==typeof e?n[o.call(e)]||&quot;object&quot;:typeof e}var f=&quot;3.6.0&quot;,S=function(e,t){return new S.fn.init(e,t)};function p(e){var t=!!e&amp;&amp;&quot;length&quot;in e&amp;&amp;e.length,n=w(e);return!m(e)&amp;&amp;!x(e)&amp;&amp;(&quot;array&quot;===n||0===t||&quot;number&quot;==typeof t&amp;&amp;0&lt;t&amp;&amp;t-1 in e)}S.fn=S.prototype={jquery:f,constructor:S,length:0,toArray:function(){return s.call(this)},get:function(e){return null==e?s.call(this):e&lt;0?this[e+this.length]:this[e]},pushStack:function(e){var t=S.merge(this.constructor(),e);return t.prevObject=this,t},each:function(e){return S.each(this,e)},map:function(n){return this.pushStack(S.map(this,function(e,t){return n.call(e,t,e)}))},slice:function(){return this.pushStack(s.apply(this,arguments))},first:function(){return this.eq(0)},last:function(){return this.eq(-1)},even:function(){return this.pushStack(S.grep(this,function(e,t){return(t+1)%2}))},odd:function(){return this.pushStack(S.grep(this,function(e,t){return t%2}))},eq:function(e){var t=this.length,n=+e+(e&lt;0?t:0);return this.pushStack(0&lt;=n&amp;&amp;n&lt;t?[this[n]]:[])},end:function(){return this.prevObject||this.constructor()},push:u,sort:t.sort,splice:t.splice},S.extend=S.fn.extend=function(){var e,t,n,r,i,o,a=arguments[0]||{},s=1,u=arguments.length,l=!1;for(&quot;boolean&quot;==typeof a&amp;&amp;(l=a,a=arguments[s]||{},s++),&quot;object&quot;==typeof a||m(a)||(a={}),s===u&amp;&amp;(a=this,s--);s&lt;u;s++)if(null!=(e=arguments[s]))for(t in e)r=e[t],&quot;__proto__&quot;!==t&amp;&amp;a!==r&amp;&amp;(l&amp;&amp;r&amp;&amp;(S.isPlainObject(r)||(i=Array.isArray(r)))?(n=a[t],o=i&amp;&amp;!Array.isArray(n)?[]:i||S.isPlainObject(n)?n:{},i=!1,a[t]=S.extend(l,o,r)):void 0!==r&amp;&amp;(a[t]=r));return a},S.extend({expando:&quot;jQuery&quot;+(f+Math.random()).replace(/\D/g,&quot;&quot;),isReady:!0,error:function(e){throw new Error(e)},noop:function(){},isPlainObject:function(e){var t,n;return!(!e||&quot;[object Object]&quot;!==o.call(e))&amp;&amp;(!(t=r(e))||&quot;function&quot;==typeof(n=v.call(t,&quot;constructor&quot;)&amp;&amp;t.constructor)&amp;&amp;a.call(n)===l)},isEmptyObject:function(e){var t;for(t in e)return!1;return!0},globalEval:function(e,t,n){b(e,{nonce:t&amp;&amp;t.nonce},n)},each:function(e,t){var n,r=0;if(p(e)){for(n=e.length;r&lt;n;r++)if(!1===t.call(e[r],r,e[r]))break}else for(r in e)if(!1===t.call(e[r],r,e[r]))break;return e},makeArray:function(e,t){var n=t||[];return null!=e&amp;&amp;(p(Object(e))?S.merge(n,&quot;string&quot;==typeof e?[e]:e):u.call(n,e)),n},inArray:function(e,t,n){return null==t?-1:i.call(t,e,n)},merge:function(e,t){for(var n=+t.length,r=0,i=e.length;r&lt;n;r++)e[i++]=t[r];return e.length=i,e},grep:function(e,t,n){for(var r=[],i=0,o=e.length,a=!n;i&lt;o;i++)!t(e[i],i)!==a&amp;&amp;r.push(e[i]);return r},map:function(e,t,n){var r,i,o ...
