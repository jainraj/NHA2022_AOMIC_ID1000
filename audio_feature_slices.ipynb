# %%
import pandas as pd

# %%
df = pd.read_csv('stft_5_97020.csv', index_col=0)

# %%
feature_list=['chroma_0','chroma_1','chroma_2','chroma_3','chroma_4']

# %%
df
# Out:
#      order  duration  onset  chroma_0  chroma_1  chroma_2  chroma_3  chroma_4
# 0        0       2.2    0.0  0.933325  1.000000  0.955135  0.863313  0.791361
# 1        1       2.2    2.2  0.124721  0.340903  1.000000  0.363422  0.075966
# 2        2       2.2    4.4  0.326873  1.000000  0.814601  0.150193  0.108478
# 3        3       2.2    6.6  0.409423  1.000000  0.754087  0.237616  0.262010
# 4        4       2.2    8.8  0.779229  1.000000  0.302295  0.149891  0.441536
# ..     ...       ...    ...       ...       ...       ...       ...       ...
# 296    296       2.2  651.2  0.245446  0.701188  0.551603  1.000000  0.636239
# 297    297       2.2  653.4  0.150492  0.572834  0.857835  1.000000  0.404873
# 298    298       2.2  655.6  1.000000  0.158747  0.093433  0.261437  0.309270
# 299    299       2.2  657.8  0.275827  0.306024  1.000000  0.205141  0.099790
# 300    300       2.2  660.0  1.000000  0.617663  0.731583  0.592029  0.765840
#
# [301 rows x 8 columns]

# %%
def get_audio_features_slices(df, features, interval=10, overlap=2):
    slices = []
    end = df.shape[0]
    i = 0
    while True:
        if i+10 >= df.shape[0]:
            break
            # Alternative? slice_temp = df.iloc[i:-1][features]
            slice_temp = df.iloc[-10:][features]
            slices.append(slice_temp)
            
        else:
            slice_temp = df.iloc[i:i+10][features]
            slices.append(slice_temp.mean(axis=0))
            i+=interval-overlap
    return slices

# %%
slices = get_audio_features_slices(df, feature_list, overlap=8)

# %%
slices
# Out:
# [chroma_0    0.414842
#  chroma_1    0.757659
#  chroma_2    0.773992
#  chroma_3    0.329385
#  chroma_4    0.254214
#  dtype: float64,
#  chroma_0    0.489915
#  chroma_1    0.823342
#  chroma_2    0.631304
#  chroma_3    0.263910
#  chroma_4    0.280473
#  dtype: float64,
#  chroma_0    0.572497
#  chroma_1    0.704210
#  chroma_2    0.537739
#  chroma_3    0.355593
#  chroma_4    0.398917
#  dtype: float64,
#  chroma_0    0.486003
#  chroma_1    0.637520
#  chroma_2    0.658663
#  chroma_3    0.380193
#  chroma_4    0.340543
#  dtype: float64,
#  chroma_0    0.575415
#  chroma_1    0.712524
#  chroma_2    0.532147
#  chroma_3    0.355986
#  chroma_4    0.441757
#  dtype: float64,
#  chroma_0    0.644169
#  chroma_1    0.657239
#  chroma_2    0.567782
#  chroma_3    0.413746
#  chroma_4    0.507095
#  dtype: float64,
#  chroma_0    0.583534
#  chroma_1    0.541503
#  chroma_2    0.702804
#  chroma_3    0.429018
#  chroma_4    0.438309
#  dtype: float64,
#  chroma_0    0.526834
# ...

# %%
pd.concat(slices).reset_index(drop=True).to_csv('audio_feature_slices.csv')

# %%
for i in range(len(slices)):
    slices[i].reset_index(drop=True).to_csv('audio_feature_slices_'+str(i+1)+'.csv')
